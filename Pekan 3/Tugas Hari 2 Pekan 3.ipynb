# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
plt.figure(figsize = (12,8))
line1, = plt.plot(x,cos,'red',label='Cosx')

line2, = plt.plot(x,cos3,linestyle='dashed',color='green',label='3 Cosx')

line3, = plt.plot(x,sin,linestyle='dashdot',color='blue', label='Sinx')

line4, = plt.plot(x,sin2,marker="x",linestyle=' ',color='yellow', label='2 Sinx')

plt.legend(loc='center')
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.title('Grafik Cos Sin')
# Out:
# Text(0.5, 1.0, 'Grafik Cos Sin')

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
