# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=10JkPB2hhDmkVUoCGFP6gpoRL1mvx0OPf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('austin_weather.csv')
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
# Date                          1319 non-null object
# TempHighF                     1319 non-null int64
# TempAvgF                      1319 non-null int64
# TempLowF                      1319 non-null int64
# DewPointHighF                 1319 non-null object
# DewPointAvgF                  1319 non-null object
# DewPointLowF                  1319 non-null object
# HumidityHighPercent           1319 non-null object
# HumidityAvgPercent            1319 non-null object
# HumidityLowPercent            1319 non-null object
# SeaLevelPressureHighInches    1319 non-null object
# SeaLevelPressureAvgInches     1319 non-null object
# SeaLevelPressureLowInches     1319 non-null object
# VisibilityHighMiles           1319 non-null object
# VisibilityAvgMiles            1319 non-null object
# VisibilityLowMiles            1319 non-null object
# WindHighMPH                   1319 non-null object
# WindAvgMPH                    1319 non-null object
# WindGustMPH                   1319 non-null object
# PrecipitationSumInches        1319 non-null object
# Events                        1319 non-null object
# dtypes: int64(3), object(18)
# memory usage: 216.5+ KB

# %% [markdown]
# <h2>Soal 1: Visualisasi Scatter Plot Perbandingan Kuantitatif</h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' yang dimana tidak bisa di ubah ke bentuk float, maka replace lah terlebih dahulu data yang bernilai '-' dengan nilai NaN, gunakan method .replace(). baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# Buahlah visualisasi perbandingan kuantitatif scatter plot, sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Pp5oIc-39mcw2vrw6xgCRM9GsvyRtPI5)

# %%
# code here
df1 = df[['DewPointAvgF','HumidityAvgPercent','TempAvgF','WindAvgMPH']]
df1 = df1.replace('-',np.nan)
df1 = df1.fillna(method='ffill')
df1 = df1.astype('float')

fig, ax = plt.subplots(figsize=(14,7))
#membuat plotting
mapbar = ax.scatter(df1['HumidityAvgPercent'],df1['DewPointAvgF'],c=df1['TempAvgF'],s=20*df1['WindAvgMPH'], alpha=0.6,cmap='coolwarm')
fig.colorbar(mapbar)

#labelling plot
ax.set_xlabel('Humidity Avg %')
ax.set_ylabel('Dew Point Avg (F)')
ax.set_title('Austin Weather')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Jawab : Warna juga dapat direpresentasikan menjadi data-data kuantitatif

# %% [markdown]
# Downoad  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# <h2>Soal 2: Preparing Data</h2>
#
# Manipulasi data tersebut dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %%
#code here
df1 = df.groupby('Genre').mean().drop(columns=['Rank','Year','Global_Sales'])
df.groupby('Genre').mean().drop(columns=['Rank','Year','Global_Sales'])
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508
# Adventure     0.082271  0.049868  0.040490     0.013072
# Fighting      0.263667  0.119481  0.103007     0.043255
# Misc          0.235906  0.124198  0.061967     0.043312
# Platform      0.504571  0.227573  0.147596     0.058228
# Puzzle        0.212680  0.087251  0.098471     0.021564
# Racing        0.287766  0.190865  0.045388     0.061865
# Role-Playing  0.219946  0.126384  0.236767     0.040060
# Shooter       0.444733  0.239137  0.029221     0.078389
# Simulation    0.211430  0.130773  0.073472     0.036355
# Sports        0.291283  0.160635  0.057702     0.057532
# Strategy      0.100881  0.066579  0.072628     0.016681

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1dR4vthSt22gM_LdfSBZCMIKPL6xd7nVl)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
import seaborn as sns
sns.set()

labels = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

x = np.arange(len(labels))  # the label locations
width = 0.8  # the width of the bars

fig, ax = plt.subplots(figsize=(19,10))
bar1 = ax.bar(x - 6*width/12, df1.iloc[0], width/12, label='Action',color="#f80013", linewidth=0)
bar2 = ax.bar(x - 5*width/12, df1.iloc[1], width/12, label='Adventure',color='#0185bd', linewidth=0)
bar2 = ax.bar(x - 4*width/12, df1.iloc[2], width/12, label='Fighting',color='#9e79d8', linewidth=0)
bar2 = ax.bar(x - 3*width/12, df1.iloc[3], width/12, label='Misc',color='#787677', linewidth=0)
bar2 = ax.bar(x - 2*width/12, df1.iloc[4], width/12, label='Platform',color='#ffc24c', linewidth=0)
bar2 = ax.bar(x - width/12, df1.iloc[5], width/12, label='Puzzle',color='#76ca34', linewidth=0)
bar2 = ax.bar(x , df1.iloc[6], width/12, label='Racing',color='#fea8b5', linewidth=0)
bar2 = ax.bar(x + width/12, df1.iloc[7], width/12, label='Role-Playing',color='#f90018', linewidth=0)
bar2 = ax.bar(x + 2*width/12, df1.iloc[8], width/12, label='Shooter',color='#0284be', linewidth=0)
bar2 = ax.bar(x + 3*width/12, df1.iloc[9], width/12, label='Simulation',color='#9e79d8', linewidth=0)
bar2 = ax.bar(x + 4*width/12, df1.iloc[10], width/12, label='Sport',color='#787776', linewidth=0)
bar2 = ax.bar(x + 5*width/12, df1.iloc[11], width/12, label='Strategy',color='#ffc44c', linewidth=0)


# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc=(0.96,0.79))

# %% [markdown]
# Jawab: Grafik menyerupai histogram. Namun, ini bukan histogram karena setiap bar yang direpresentasikan diwarnai yang berbeda-beda

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1A2s9Uy2i471VEYIZqMoVUIlZnVOUc8ha)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 4: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %% [markdown]
# Jawab: Nilai Mean Series pada grafik berbanding lurus dengan besar dimensi y pad setiap bar-bar yang di-stack

# %%
#code here
labels = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

x = np.arange(len(labels))  # the label locations
width = 0.8  # the width of the bars

fig, ax = plt.subplots(figsize=(19,10))
ax.bar(labels, df1.iloc[0], width, label='Action',color="#f80013", linewidth=0)
ax.bar(labels, df1.iloc[1], width, bottom=df1.iloc[0],label='Adventure',color='#0185bd', linewidth=0)
ax.bar(labels, df1.iloc[2], width, bottom=df1.iloc[1]+df1.iloc[0],label='Fighting',color='#9e79d8', linewidth=0)
ax.bar(labels, df1.iloc[3], width, bottom=df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Misc',color='#787677', linewidth=0)
ax.bar(labels, df1.iloc[4], width, bottom=df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Platform',color='#ffc24c', linewidth=0)
ax.bar(labels, df1.iloc[5], width, bottom=df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Puzzle',color='#76ca34', linewidth=0)
ax.bar(labels, df1.iloc[6], width, bottom=df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Racing',color='#fea8b5', linewidth=0)
ax.bar(labels, df1.iloc[7], width, bottom=df1.iloc[6]+df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Role-Playing',color='#f90018', linewidth=0)
ax.bar(labels, df1.iloc[8], width, bottom=df1.iloc[7]+df1.iloc[6]+df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Shooter',color='#0284be', linewidth=0)
ax.bar(labels, df1.iloc[9], width, bottom=df1.iloc[8]+df1.iloc[7]+df1.iloc[6]+df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Simulation',color='#9e79d8', linewidth=0)
ax.bar(labels, df1.iloc[10], width, bottom=df1.iloc[9]+df1.iloc[8]+df1.iloc[7]+df1.iloc[6]+df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Sport',color='#787776', linewidth=0)
ax.bar(labels, df1.iloc[11], width, bottom=df1.iloc[10]+df1.iloc[9]+df1.iloc[8]+df1.iloc[7]+df1.iloc[6]+df1.iloc[5]+df1.iloc[4]+df1.iloc[3]+df1.iloc[2]+df1.iloc[1]+df1.iloc[0],label='Strategy',color='#ffc44c', linewidth=0)


# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc=(0.96,0.79))

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1_yis-3aZsEbsk68tpoPHoNlFftaz2GrO)
