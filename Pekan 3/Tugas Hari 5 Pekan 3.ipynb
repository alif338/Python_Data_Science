# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('diamonds.csv')

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
f, ax = plt.subplots(figsize=(13, 13))
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",hue="clarity", size="depth",palette="ch:r=-.2,d=.3_r",hue_order=clarity_ranking,sizes=(1, 8), linewidth=0,data=df)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1OyzNnrnkJ7TL8DIyh_2O97WuzesyLL7W)

# %% [markdown]
# # Soal 2: Facet Grid

# %% [markdown]
# Gunakan fungsi hexbin berikut untuk diterapkan pada mapping dari facetgridnya sehingga dihasilkan output sesuai expected.
#
# ```
# def hexbin(x, y, color, **kwargs):
#     cmap = sns.light_palette(color, as_cmap=True)
#     plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)
# ```

# %%
#code here
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

df1 = df[df['cut']=="Ideal"]
df2 = df[df['cut']=="Premium"]
df3 = df[df['cut']=="Good"]
df4 = df[df['cut']=="Very Good"]
df5 = df[df['cut']=="Fair"]
sns.set()
g = sns.FacetGrid(df, col="cut",hue="cut",height=5)
g.map(hexbin,"carat","price",extent=[0, 3, 0, 20000])
#g = g.map(hexbin(x,y,color), "carat", "price", edgecolor="w")
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1ZG6Uu0R_8mPAjpwublowrdUM6Hd1OXkI)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price sehingga dihasilkan output sesuai expected.

# %%
df3 = df.sample(n=300, random_state=123)
#code here
g = sns.pairplot(df3,vars= ['carat', 'depth', 'table', 'price'],hue="cut", markers=["+","o","s","D","x"],corner=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a5bc29196e02> in <module>
#       1 df3 = df.sample(n=300, random_state=123)
#       2 #code here
# ----> 3 g = sns.pairplot(df3,vars= ['carat', 'depth', 'table', 'price'],hue="cut", markers=["+","o","s","D","x"],corner=True)
#
# TypeError: pairplot() got an unexpected keyword argument 'corner'

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1N3guRLAn5sIhfzzKFdvf1cZpmtEc-cw9)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
#code here
g = sns.jointplot('carat','price',data = df3, kind="kde",color="b")

# %%
import scipy.stats as stats

g = sns.jointplot('carat','price',data=df3, kind="reg")
g.annotate(stats.pearsonr)
plt.show()
# Out:
# C:\Users\ALIF\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=1xX5Jq38-rr_oFD-eDRbBYCBA24Nmw2C5)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1QXY89CXRe1BzU0k7OBrr2fTn8WwIhWHo)
